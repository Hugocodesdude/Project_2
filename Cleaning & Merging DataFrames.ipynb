# %% [markdown]
# # Cleaning & Merging DataFrames

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
import numpy as np

# %% [markdown]
# ## EU Economic Data

# %%
economic_info= pd.read_csv("./data/economic_info.csv")

# %%
economic_info
# Out:
#       Countries  Population    Annual GDP  Annual GDP.1 GDP per capita  \
# 0       Austria     8978929     €406,149M     $477,084M        €45,370
# 1       Belgium    11631136     €502,312M     $599,107M        €43,340
# 2      Bulgaria     6838937      €71,077M      $80,327M        €10,330
# 3       Croatia     3879074      €57,200M      $67,707M        €14,750
# 4        Cyprus      904705      €24,019M      $27,738M        €26,680
# 5       Czechia    10516707     €238,238M     $281,778M        €22,270
# 6       Denmark     5873420     €336,719M     $398,303M        €57,520
# 7       Estonia     1331796      €31,445M      $37,216M        €22,580
# 8       Finland     5548241     €251,367M     $297,575M        €45,360
# 9        France    67842582   €2,500,870M   $2,957,425M        €36,660
# 10      Germany    83237124   €3,601,750M   $4,262,767M        €43,290
# 11       Greece    10603810     €181,675M     $216,384M        €17,010
# ...

# %% [markdown]
# ## Refugee Data

# %%
refugee_df= pd.read_csv("./data/refugee_df.csv")

# %%
refugee_df
# Out:
#             Countries  Refugees in thousands
# 0             Austria                   8308
# 1             Belgium                   5616
# 2            Bulgaria                  13616
# 3             Croatia                    185
# 4              Cyprus                   1679
# 5             Czechia                  44226
# 6             Denmark                    335
# 7             Estonia                   3597
# 8             Finland                   4079
# 9              France                    105
# 10            Germany                  70915
# 11             Greece                   1941
# 12            Hungary                     30
# 13            Iceland                    164
# 14            Ireland                   5483
# 15              Italy                  15761
# 16             Latvia                   4091
# 17       Lichtenstein                     31
# 18          Lithuania                   6705
# 19         Luxembourg                    656
# ...

# %%
refugee_df.rename(columns = {' Countries':'Countries'}, inplace = True)

# %%
refugee_df.columns
# Out:
# Index(['Countries', 'Refugees in thousands'], dtype='object')

# %% [markdown]
# # Merging EU Economic Data with Refugee Data

# %%
# KeyError: 'Countries'
# result = pd.merge(economic_info,refugee_df, on="Countries")

# %%
def merge_dataframe(df1,df2,column):
    
    return pd.merge(df1,df2,how='outer', on=column, left_index=False, right_index=False, sort=True)

# %%
new_data_frame = merge_dataframe(economic_info,refugee_df,"Countries")

# %%
new_data_frame
# Out:
#             Countries   Population    Annual GDP  Annual GDP.1 GDP per capita  \
# 0             Austria    8978929.0     €406,149M     $477,084M        €45,370
# 1             Belgium   11631136.0     €502,312M     $599,107M        €43,340
# 2            Bulgaria    6838937.0      €71,077M      $80,327M        €10,330
# 3             Croatia    3879074.0      €57,200M      $67,707M        €14,750
# 4              Cyprus     904705.0      €24,019M      $27,738M        €26,680
# 5             Czechia   10516707.0     €238,238M     $281,778M        €22,270
# 6             Denmark    5873420.0     €336,719M     $398,303M        €57,520
# 7             Estonia    1331796.0      €31,445M      $37,216M        €22,580
# 8             Finland    5548241.0     €251,367M     $297,575M        €45,360
# 9              France   67842582.0   €2,500,870M   $2,957,425M        €36,660
# 10            Germany   83237124.0   €3,601,750M   $4,262,767M        €43,290
# ...

# %%
new_data_frame.to_csv("./data/new_data_frame.csv", index=False)

# %%
new_data_frame.drop([13, 17, 21, 23, 27, 32, 33, 34], axis = 0, inplace = True)

# %%
#new_data_frame.dropna(axis=0, inplace=True, how="all")

# %%
new_data_frame
# Out:
#       Countries  Population   Annual GDP Annual GDP.1 GDP per capita  \
# 0       Austria   8978929.0    €406,149M    $477,084M        €45,370
# 1       Belgium  11631136.0    €502,312M    $599,107M        €43,340
# 2      Bulgaria   6838937.0     €71,077M     $80,327M        €10,330
# 3       Croatia   3879074.0     €57,200M     $67,707M        €14,750
# 4        Cyprus    904705.0     €24,019M     $27,738M        €26,680
# 5       Czechia  10516707.0    €238,238M    $281,778M        €22,270
# 6       Denmark   5873420.0    €336,719M    $398,303M        €57,520
# 7       Estonia   1331796.0     €31,445M     $37,216M        €22,580
# 8       Finland   5548241.0    €251,367M    $297,575M        €45,360
# 9        France  67842582.0  €2,500,870M  $2,957,425M        €36,660
# 10      Germany  83237124.0  €3,601,750M  $4,262,767M        €43,290
# 11       Greece  10603810.0    €181,675M    $216,384M        €17,010
# 12      Hungary   9689010.0    €153,759M    $182,281M        €15,840
# ...

# %%
new_data_frame.to_csv("./data/new_data_frame.csv", index=False)

# %% [markdown]
# ## Distance Data

# %%
distance_df= pd.read_csv("./data/distance_df.csv")

# %%
distance_df["Countries to sort"].to_string()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Countries to sort'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
distance_df["Countries to sort"].unique()

# %%
distance_df.head()

# %%
distance_df.columns

# %%
# regrez to remove km from distance
distance_df["Distance from Ukraine in km"] = distance_df["Distance from Ukraine in km"].str.extract(r"(\d,\d{1,})")

# %%
distance_df

# %%
distance_df.sort_values(by='Distance from Ukraine in km',ascending=True)

# %%
distance_df["Mileage"] = distance_df["Mileage"].str.extract(r"(\d,\d{1,})")

# %%
distance_df

# %%
distance_df.to_csv("./data/distance_df.csv", index=False)

# %%
distance_df.drop([0, 1, 2, 3, 4, 245, 246, 247, 248, 249], axis = 0, inplace = True)

# %%
distance_df

# %%
distance_df.drop([5, 6, 7, 8, 9, 240, 242, 243, 244], axis = 0, inplace = True)

# %%
distance_df

# %%
distance_df.drop([10, 12, 13, 14, 236, 237, 238, 239], axis = 0, inplace = True)

# %%
distance_df

# %%
distance_df.drop([15, 17, 18, 232, 233, 235], axis = 0, inplace = True)

# %%
distance_df.sample(200)

# %%
distance_df.drop([217,45, 81,185,60, 196, 214], axis = 0, inplace = True)

# %%
distance_df.sample(200)

# %%
distance_df.drop([139,220, 22, 157 , 132, 47, 74, 90], axis = 0, inplace = True)

# %%
distance_df.sample(200)

# %%
distance_df.drop([98, 58, 171, 169, 207, 83, 146, 109], axis = 0, inplace = True)

# %%
distance_df

# %%
distance_df.sample(121)

# %%
distance_df.drop([219, 108, 183, 134, 140, 77, 205, 202, 124, 195], axis = 0, inplace = True)

# %%
distance_df.tail(10)

# %%
distance_df.drop([224, 225, 226, 227, 228, 229, 230, 231, 234], axis = 0, inplace = True)

# %%
distance_df.tail(10)

# %%
distance_df.drop([211, 212, 215, 216, 218,221,222,223], axis = 0, inplace = True)

# %%
distance_df.tail(10)

# %%
distance_df.drop([179,180,181,182,184,187], axis = 0, inplace = True)

# %%
distance_df.sample(20)

# %%
distance_df

# %%
distance_df.drop([24], axis = 0, inplace = True)

# %%
distance_df

# %%
distance_df.drop([41,103,133], axis = 0, inplace = True)

# %%
distance_df

# %%
distance_df.to_csv("./data/distance_df.csv", index=False)

# %%
#distance_df["Countries to sort"].str.replace('Distance from Austria to Ukraine':'Austria', 'Distance from Belgium to Ukraine':'Belgium', 'Distance from Bulgaria to Ukraine':'Bulgaria', 'Distance from Cyprus to Ukraine': 'Cyprus', 'Distance from Czech Republic to Ukraine':'Czechia', 'Distance from Germany to Ukraine': 'Germany', 'Distance from Denmark to Ukraine':'Denmark','Distance from Estonia to Ukraine':'Estonia','Distance from Spain to Ukraine':'Spain', 'Distance from Finland to Ukraine':'Finland', 'Distance from France to Ukraine': 'France', 'Distance from Greece to Ukraine': 'Greece', 'Distance from Croatia to Ukraine': 'Croatia', 'Distance from Hungary to Ukraine':'Hungary', 'Distance from Ireland to Ukraine':'Ireland', 'Distance from Italy to Ukraine' : 'Italy', 'Distance from Liechtenstein to Ukraine': 'Liechtenstein', 'Distance from Latvia to Ukraine':'Latvia', 'Distance from Malta to Ukraine':'Malta', 'Distance from Netherlands to Ukraine' : 'Netherlands', 'Distance from Poland to Ukraine' : 'Poland', 'Distance from Portugal to Ukraine' : 'Portugal', 'Distance from Romania to Ukraine': 'Romania', 'Distance from Sweden to Ukraine' : 'Sweden', 'Distance from Slovenia to Ukraine' : 'Slovenia', 'Distance from Ukraine to Luxembourg' : 'Luxembourg')

# %%
#distance_df["Countries to sort"].str.replace("Distance from Austria to Ukraine","Austria", inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Austria to Ukraine','Austria', inplace=True)

# %%
distance_df

# %%
#distance_df["Countries to sort"] = distance_df["Countries to sort"].str.extract(r"(")

# %%
distance_df['Countries to sort'].replace('Distance from Bulgaria to Ukraine','Bulgaria', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Denmark to Ukraine', 'Denmark', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Estonia to Ukraine', 'Estonia', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Spain to Ukraine', 'Spain', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Finland to Ukraine', 'Finland', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from France to Ukraine', 'France', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Greece to Ukraine', 'Greece', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Croatia to Ukraine', 'Croatia', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Hungary to Ukraine', 'Hungary', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Ireland to Ukraine', 'Ireland', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Italy to Ukraine', 'Italy', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Liechtenstein to Ukraine', 'Liechtenstein', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Lithuania to Ukraine', 'Lithuania', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Latvia to Ukraine', 'Latvia', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Malta to Ukraine', 'Malta', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Netherlands to Ukraine', 'Netherlands', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Poland to Ukraine', 'Poland', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Portugal to Ukraine', 'Portugal', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Romania to Ukraine', 'Romania', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Sweden to Ukraine', 'Sweden', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Slovenia to Ukraine', 'Slovenia', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Slovakia to Ukraine', 'Slovakia', inplace=True)

# %%
distance_df['Countries to sort'].replace('Distance from Ukraine to Luxembourg', 'Luxembourg', inplace=True)

# %%
distance_df

# %%
#distance_df.at[index,'column']= value

# %%
distance_df.at[21,'Distance from Ukraine in km']= 767
distance_df.at[94,'Distance from Ukraine in km']= 881
distance_df.at[127,'Distance from Ukraine in km']= 905
distance_df.at[168,'Distance from Ukraine in km']= 941
distance_df.at[177,'Distance from Ukraine in km']= 541
distance_df.at[190,'Distance from Ukraine in km']= 844

# %%
distance_df

# %%
distance_df = distance_df.drop(columns=["Mileage"])

# %%
distance_df

# %%
distance_df.rename(columns = {'Countries to sort':'Countries'}, inplace = True)

# %%
# Sort alphabetically 
distance_df.sort_values(by='Countries', ascending=True)

# %%
distance_df.to_csv("./data/distance_df.csv", index=False)

# %% [markdown]
# ## merge Distance with DataFrame

# %%
def merge_dataframe_two(df1,df2,column):
    
    return pd.merge(df1,df2,how='outer', on=column, left_index=False, right_index=False, sort=True)

# %%
project_data = merge_dataframe_two(new_data_frame,distance_df,"Countries")

# %%
project_data

# %%
project_data.to_csv("./data/project_data.csv", index=False)

# %%
project_data.rename(columns = {'Annual GDP':'Annual GDP (M.€.)', 'Annual GDP.1':'Annual GDP (M.$.)', 'GDP per capita':'GDP per capita (€)', 'GDP per capita.1 (M.$.':'GDP per capita.1 ($)' }, inplace = True)

# %%
project_data.rename(columns = {'GDP per capita.1 (M.$.)':'GDP per capita.1 ($)'}, inplace = True)

# %%
project_data

# %%
#project_data["Mileage"] = project_data["Mileage"].str.extract(r"(\d,\d{1,})")
